# %%
import pandas as pd

landmark_back_df = pd.read_csv("./landmark_results/1_GehenH.csv", index_col=0)
landmark_site_df = pd.read_csv("./landmark_results/1_GehenS.csv", index_col=0)

#only y coordinates or all coordinates????????
def adjust_y_coordinates(landmark_back_df, landmark_site_df):
    for column in landmark_back_df.columns:
        if column[-1:] == "y":
            df_back_column_mean = landmark_back_df[column].mean()
            df_site_column_mean = landmark_site_df[column].mean()
            delta_mean = df_back_column_mean - df_site_column_mean
            landmark_site_df[column] += delta_mean
    return landmark_back_df, landmark_site_df

def combine_angles(landmark_back_df, landmark_site_df, filename):
    landmark_combined_df = (landmark_back_df + landmark_site_df) / 2
    landmark_combined_df.to_csv("./landmark_results_combined/" + filename + ".csv")
    return landmark_combined_df

landmark_site_df
# Out:
#       LEFT_HIP_x  LEFT_HIP_y  LEFT_HIP_z  LEFT_HIP_vis  RIGHT_HIP_x  \
# 0       0.611455    0.499553   -0.209067      0.999858     0.547920
# 1       0.593775    0.499720   -0.212537      0.999857     0.550578
# 2       0.574395    0.500599   -0.210093      0.999858     0.554172
# 3       0.576513    0.500656   -0.210192      0.999860     0.547946
# 4       0.577262    0.495919   -0.217770      0.999867     0.544567
# ...          ...         ...         ...           ...          ...
# 1797    0.548229    0.494355   -0.190226      0.999395     0.580412
# 1798    0.543731    0.493426   -0.206700      0.999391     0.567164
# 1799    0.546426    0.487480   -0.225952      0.999425     0.550757
# 1800    0.547289    0.479414   -0.218001      0.999441     0.555458
# 1801    0.554585    0.474780   -0.206047      0.999472     0.565036
#
#       RIGHT_HIP_y  RIGHT_HIP_z  RIGHT_HIP_vis  LEFT_KNEE_x  LEFT_KNEE_y  ...  \
# 0        0.499355     0.208528       0.999491     0.718172     0.631951  ...
# 1        0.499606     0.211988       0.999487     0.718146     0.631304  ...
# 2        0.499790     0.209575       0.999500     0.680241     0.632088  ...
# 3        0.499723     0.209685       0.999529     0.643342     0.634229  ...
# 4        0.494050     0.217271       0.999564     0.608234     0.634348  ...
# ...           ...          ...            ...          ...          ...  ...
# 1797     0.495266     0.190118       0.999048     0.432820     0.614995  ...
# 1798     0.494922     0.206500       0.999037     0.441261     0.615037  ...
# 1799     0.489664     0.225633       0.999067     0.475776     0.614275  ...
# 1800     0.483498     0.217762       0.999076     0.499021     0.614188  ...
# 1801     0.477579     0.205675       0.999115     0.518392     0.613728  ...
#
#       RIGHT_HEEL_z  RIGHT_HEEL_vis  LEFT_FOOT_INDEX_x  LEFT_FOOT_INDEX_y  \
# 0         0.467481        0.923453           0.833716           0.797767
# 1         0.476157        0.924564           0.836418           0.797132
# 2         0.416107        0.925228           0.861726           0.795578
# 3         0.441709        0.925689           0.873448           0.787205
# 4         0.454591        0.924797           0.863669           0.782048
# ...            ...             ...                ...                ...
# 1797      0.227189        0.884373           0.302902           0.787129
# 1798      0.267945        0.890035           0.335113           0.793721
# 1799      0.409568        0.894809           0.369596           0.798123
# 1800      0.461670        0.896138           0.424396           0.797215
# 1801      0.411209        0.886644           0.598564           0.795150
#
#       LEFT_FOOT_INDEX_z  LEFT_FOOT_INDEX_vis  RIGHT_FOOT_INDEX_x  \
# 0             -0.175474             0.995791            0.281864
# 1             -0.165653             0.995947            0.281413
# 2             -0.166602             0.996058            0.321844
# 3             -0.123232             0.996140            0.358159
# 4             -0.124244             0.996296            0.378171
# ...                 ...                  ...                 ...
# 1797           0.005504             0.968743            0.849806
# 1798          -0.012857             0.970877            0.846294
# 1799          -0.196394             0.973257            0.812287
# 1800          -0.147922             0.973871            0.742041
# 1801          -0.067020             0.974952            0.577161
#
#       RIGHT_FOOT_INDEX_y  RIGHT_FOOT_INDEX_z  RIGHT_FOOT_INDEX_vis
# 0               0.761949            0.372658              0.977445
# 1               0.761126            0.374440              0.977949
# 2               0.762307            0.316647              0.977543
# 3               0.768780            0.328453              0.977271
# 4               0.773996            0.331921              0.977261
# ...                  ...                 ...                   ...
# 1797            0.778771            0.163872              0.866584
# 1798            0.773329            0.203298              0.872696
# 1799            0.768493            0.336659              0.879376
# 1800            0.768563            0.380716              0.879164
# 1801            0.772845            0.336107              0.873755
#
# [1802 rows x 40 columns]

# %%
landmark_back_df = adjust_y_coordinates(landmark_back_df, landmark_site_df)[0]
landmark_site_df = adjust_y_coordinates(landmark_back_df, landmark_site_df)[1]
landmark_site_df
# Out:
#       Unnamed: 0  LEFT_HIP_x  LEFT_HIP_y  LEFT_HIP_z  LEFT_HIP_vis  \
# 0              0    0.611455    0.479137   -0.209067      0.999858
# 1              1    0.593775    0.479303   -0.212537      0.999857
# 2              2    0.574395    0.480183   -0.210093      0.999858
# 3              3    0.576513    0.480240   -0.210192      0.999860
# 4              4    0.577262    0.475502   -0.217770      0.999867
# ...          ...         ...         ...         ...           ...
# 1797        1797    0.548229    0.473938   -0.190226      0.999395
# 1798        1798    0.543731    0.473010   -0.206700      0.999391
# 1799        1799    0.546426    0.467063   -0.225952      0.999425
# 1800        1800    0.547289    0.458998   -0.218001      0.999441
# 1801        1801    0.554585    0.454363   -0.206047      0.999472
#
#       RIGHT_HIP_x  RIGHT_HIP_y  RIGHT_HIP_z  RIGHT_HIP_vis  LEFT_KNEE_x  ...  \
# 0        0.547920     0.476816     0.208528       0.999491     0.718172  ...
# 1        0.550578     0.477067     0.211988       0.999487     0.718146  ...
# 2        0.554172     0.477251     0.209575       0.999500     0.680241  ...
# 3        0.547946     0.477183     0.209685       0.999529     0.643342  ...
# 4        0.544567     0.471511     0.217271       0.999564     0.608234  ...
# ...           ...          ...          ...            ...          ...  ...
# 1797     0.580412     0.472727     0.190118       0.999048     0.432820  ...
# 1798     0.567164     0.472383     0.206500       0.999037     0.441261  ...
# 1799     0.550757     0.467125     0.225633       0.999067     0.475776  ...
# 1800     0.555458     0.460959     0.217762       0.999076     0.499021  ...
# 1801     0.565036     0.455040     0.205675       0.999115     0.518392  ...
#
#       RIGHT_HEEL_z  RIGHT_HEEL_vis  LEFT_FOOT_INDEX_x  LEFT_FOOT_INDEX_y  \
# 0         0.467481        0.923453           0.833716           0.804718
# 1         0.476157        0.924564           0.836418           0.804082
# 2         0.416107        0.925228           0.861726           0.802529
# 3         0.441709        0.925689           0.873448           0.794156
# 4         0.454591        0.924797           0.863669           0.788999
# ...            ...             ...                ...                ...
# 1797      0.227189        0.884373           0.302902           0.794079
# 1798      0.267945        0.890035           0.335113           0.800671
# 1799      0.409568        0.894809           0.369596           0.805073
# 1800      0.461670        0.896138           0.424396           0.804165
# 1801      0.411209        0.886644           0.598564           0.802101
#
#       LEFT_FOOT_INDEX_z  LEFT_FOOT_INDEX_vis  RIGHT_FOOT_INDEX_x  \
# 0             -0.175474             0.995791            0.281864
# 1             -0.165653             0.995947            0.281413
# 2             -0.166602             0.996058            0.321844
# 3             -0.123232             0.996140            0.358159
# 4             -0.124244             0.996296            0.378171
# ...                 ...                  ...                 ...
# 1797           0.005504             0.968743            0.849806
# 1798          -0.012857             0.970877            0.846294
# 1799          -0.196394             0.973257            0.812287
# 1800          -0.147922             0.973871            0.742041
# 1801          -0.067020             0.974952            0.577161
#
#       RIGHT_FOOT_INDEX_y  RIGHT_FOOT_INDEX_z  RIGHT_FOOT_INDEX_vis
# 0               0.774774            0.372658              0.977445
# 1               0.773952            0.374440              0.977949
# 2               0.775133            0.316647              0.977543
# 3               0.781606            0.328453              0.977271
# 4               0.786821            0.331921              0.977261
# ...                  ...                 ...                   ...
# 1797            0.791596            0.163872              0.866584
# 1798            0.786155            0.203298              0.872696
# 1799            0.781318            0.336659              0.879376
# 1800            0.781389            0.380716              0.879164
# 1801            0.785671            0.336107              0.873755
#
# [1802 rows x 41 columns]

# %%
landmark_combined_df = combine_angles(landmark_back_df, landmark_site_df, "Gehen-6,5-combined")
landmark_combined_df
# Out:
#       Unnamed: 0  LEFT_HIP_x  LEFT_HIP_y  LEFT_HIP_z  LEFT_HIP_vis  \
# 0            0.0    0.532058    0.479212   -0.142287      0.999877
# 1            1.0    0.524701    0.479231   -0.134889      0.999878
# 2            2.0    0.515060    0.478354   -0.135640      0.999878
# 3            3.0    0.516525    0.478377   -0.136278      0.999877
# 4            4.0    0.516934    0.474801   -0.143422      0.999884
# ...          ...         ...         ...         ...           ...
# 1797      1797.0    0.501300    0.475920   -0.095340      0.999288
# 1798      1798.0    0.497933    0.475011   -0.122816      0.999323
# 1799      1799.0    0.498501    0.471946   -0.146501      0.999374
# 1800      1800.0    0.498941    0.461514   -0.148502      0.999414
# 1801      1801.0    0.502198    0.456315   -0.151962      0.999455
#
#       RIGHT_HIP_x  RIGHT_HIP_y  RIGHT_HIP_z  RIGHT_HIP_vis  LEFT_KNEE_x  ...  \
# 0        0.565910     0.477710     0.141770       0.999588     0.584333  ...
# 1        0.568582     0.477581     0.134421       0.999587     0.584404  ...
# 2        0.571024     0.476033     0.135255       0.999596     0.565374  ...
# 3        0.569907     0.475934     0.135878       0.999617     0.546331  ...
# 4        0.570635     0.471361     0.142866       0.999644     0.528054  ...
# ...           ...          ...          ...            ...          ...  ...
# 1797     0.588171     0.475151     0.094891       0.999291     0.446065  ...
# 1798     0.579851     0.474200     0.122109       0.999302     0.450484  ...
# 1799     0.570507     0.470493     0.145710       0.999331     0.467649  ...
# 1800     0.572876     0.461364     0.147723       0.999350     0.478486  ...
# 1801     0.577696     0.454795     0.151353       0.999377     0.486641  ...
#
#       RIGHT_HEEL_z  RIGHT_HEEL_vis  LEFT_FOOT_INDEX_x  LEFT_FOOT_INDEX_y  \
# 0         0.477349        0.927340           0.644840           0.837390
# 1         0.490500        0.927961           0.648904           0.837684
# 2         0.402027        0.929520           0.661032           0.835802
# 3         0.379935        0.931651           0.666840           0.829655
# 4         0.364615        0.932781           0.661407           0.815607
# ...            ...             ...                ...                ...
# 1797      0.141137        0.905234           0.395961           0.784376
# 1798      0.185384        0.909542           0.412522           0.790471
# 1799      0.368550        0.912967           0.429219           0.794999
# 1800      0.362437        0.914617           0.459687           0.799475
# 1801      0.410756        0.910043           0.545977           0.796459
#
#       LEFT_FOOT_INDEX_z  LEFT_FOOT_INDEX_vis  RIGHT_FOOT_INDEX_x  \
# 0             -0.130704             0.978638            0.403726
# 1             -0.162735             0.979038            0.402810
# 2             -0.155847             0.979210            0.407852
# 3             -0.079843             0.979545            0.425047
# 4             -0.081549             0.980891            0.437136
# ...                 ...                  ...                 ...
# 1797           0.080271             0.904874            0.713829
# 1798          -0.028755             0.912990            0.710358
# 1799          -0.074813             0.920367            0.690962
# 1800          -0.129139             0.926592            0.653149
# 1801          -0.053814             0.931801            0.565944
#
#       RIGHT_FOOT_INDEX_y  RIGHT_FOOT_INDEX_z  RIGHT_FOOT_INDEX_vis
# 0               0.759613            0.430959              0.930049
# 1               0.761544            0.432533              0.931127
# 2               0.776084            0.329299              0.932761
# 3               0.798090            0.287772              0.936052
# 4               0.794737            0.282048              0.939858
# ...                  ...                 ...                   ...
# 1797            0.821113            0.070296              0.852781
# 1798            0.800300            0.098857              0.860879
# 1799            0.787213            0.321498              0.867933
# 1800            0.786311            0.299057              0.871919
# 1801            0.780987            0.345845              0.871213
#
# [1802 rows x 41 columns]

# %%
import os

directory_in_str = "J:\Kai Kustermann\HDM\Semester 7\Big Data\Videoediting and Modelbuilding\landmark_results"
directory = os.fsencode(directory_in_str)

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    #without .csv
    filename_edited = filename[:-4]

    if filename.endswith(".csv") and filename_edited.endswith("H"):
        filename_site_edited = filename_edited[:-1] + "S"
        landmark_back_df = pd.read_csv("./landmark_results/{}.csv".format(filename_edited), index_col=0)
        landmark_site_df = pd.read_csv("./landmark_results/{}.csv".format(filename_site_edited), index_col=0)
        landmark_back_df = adjust_y_coordinates(landmark_back_df, landmark_site_df)[0]
        landmark_site_df = adjust_y_coordinates(landmark_back_df, landmark_site_df)[1]
        landmark_combined_df = combine_angles(landmark_back_df, landmark_site_df, filename_edited[:-1] + "_combined")
        continue
    else:
        continue
