# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

landmarks_df = pd.read_json("./landmark_results/Gehen-6,5-seite.json")
landmarks_df 

#slice from the first column that we need (from hip onwards)
landmarks_df = landmarks_df.loc[:, 'LEFT_HIP_x':]
landmarks_df
# Out:
#       LEFT_HIP_x  LEFT_HIP_y  LEFT_HIP_z  LEFT_HIP_vis  RIGHT_HIP_x  \
# 0       0.636351    0.496495   -0.185963      0.999884     0.563692
# 1       0.624691    0.499795   -0.200122      0.999876     0.563425
# 2       0.609082    0.500591   -0.206077      0.999875     0.562974
# 3       0.592688    0.500482   -0.204172      0.999876     0.564181
# 4       0.591963    0.494395   -0.203446      0.999879     0.557629
# ...          ...         ...         ...           ...          ...
# 2059    0.429694    0.490006   -0.139772      0.999389     0.477699
# 2060    0.428318    0.495272   -0.143153      0.999394     0.476984
# 2061    0.418085    0.495362   -0.146170      0.999398     0.475536
# 2062    0.413558    0.494036   -0.176528      0.999416     0.459786
# 2063    0.409550    0.494912   -0.189420      0.999433     0.446404
#
#       RIGHT_HIP_y  RIGHT_HIP_z  RIGHT_HIP_vis  LEFT_KNEE_x  LEFT_KNEE_y  \
# 0        0.498984     0.185542       0.999290     0.753572     0.634008
# ...

# %%
def plot_features():
    for column in landmarks_df.columns:   
        plt.plot(landmarks_df[column])
        plt.xlabel('frame')
        if landmarks_df[column].name[-4:] == "_vis":
            plt.ylabel('visibility')
        else:
            plt.ylabel('landmark_position')
        plt.title(column)
        plt.show()

plot_features()
