# %%
import pandas as pd
import matplotlib.pyplot as plt

df_back = pd.read_csv("../landmark_results/1_GehenH.csv", index_col=0)
df_site = pd.read_csv("../landmark_results/1_GehenS.csv", index_col=0)

for column in df_site.columns:
    if column[-1:] == "x":
        df_comb = pd.DataFrame()
        df_comb[column] = df_site[column]
        df_comb[column[:-1] + "z"] = df_back[column[:-1] + "z"]
        df_comb.plot()
